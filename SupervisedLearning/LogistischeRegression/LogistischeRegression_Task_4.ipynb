# %%
# Data import 
𝐷={((0.3,0.3),1),((0.24,0.26),4),((0.33,0.2),2),((0.35,0.4),3),((0.39,0.38),3),((0.42,0.26),1)}

# %%
# Structure Data
import numpy as np
import pandas as pd

X = np.array([x for x, _ in D])
y = np.array([y for _, y in D])

# %%
# Data visulaization
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X[:, 0], X[:, 1], y, c=y, cmap='coolwarm', s=100)

ax.set_xlabel("Feature 1")
ax.set_ylabel("Feature 2")
ax.set_zlabel("Zielwert (y)")
plt.show()

# %%
# Polynomielle Erweiterung
from sklearn.preprocessing import PolynomialFeatures

poly = PolynomialFeatures(degree=2, include_bias=False)
X_poly = poly.fit_transform(X)

# %%
# Logistische Regression 
from sklearn.linear_model import LogisticRegression#
clf = LogisticRegression(multi_class='ovr').fit(X_poly,y)
# Out:
# /Users/maltescharf/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_logistic.py:1256: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. Use OneVsRestClassifier(LogisticRegression(..)) instead. Leave it to its default value to avoid this warning.
#   warnings.warn(

# %%
# Koeffizient #1
np.round(clf.intercept_,3)
# Out:
# array([-0.696, -1.567, -0.791, -1.551])

# %%
# Restliche Koeffizienten
np.round(clf.coef_,3)
# Out:
# array([[ 0.043, -0.04 ,  0.03 , -0.006, -0.032],
#        [-0.008, -0.099, -0.009, -0.036, -0.055],
#        [ 0.062,  0.178,  0.038,  0.082,  0.113],
#        [-0.098, -0.04 , -0.06 , -0.04 , -0.027]])
