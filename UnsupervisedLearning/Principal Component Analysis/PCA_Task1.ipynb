# %%
# Datensatz

𝐸=np.array([[-1.222,-1.297,-1.648],[-0.604,-0.208,1.436],[1.247,0.809,-0.414],[1.247,1.826,-0.846],[-0.693,0.301,1.128],[-0.869,-1.006,0.141],[0.894,-0.425,0.203]])
E
# Out:
# array([[-1.222, -1.297, -1.648],
#        [-0.604, -0.208,  1.436],
#        [ 1.247,  0.809, -0.414],
#        [ 1.247,  1.826, -0.846],
#        [-0.693,  0.301,  1.128],
#        [-0.869, -1.006,  0.141],
#        [ 0.894, -0.425,  0.203]])

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D


# Aufteilen in x, y, z
x = E[:, 0]
y = E[:, 1]
z = E[:, 2]

# 3D-Plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x, y, z)

# Achsentitel
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.show()
# Out:
# Text(0.5, 0, 'Z')

# %%
# z-transformation
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(E)
E_scaled = scaler.transform(E)

# %%
# plot standardisierte

# Aufteilen in x, y, z
x = E_scaled[:, 0]
y = E_scaled[:, 1]
z = E_scaled[:, 2]

# 3D-Plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x, y, z)

# Achsentitel
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.show()

# %%
# Hauptkomponentenanalyse mit 2 Komponenten
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
pca.fit(E_scaled)

pca.explained_variance_.round(3)
# Out:
# array([2.065, 1.172])

# %%
# Hauptkomponentenanalyse mit 2 Komponenten
from sklearn.decomposition import PCA

pca = PCA(n_components=3)
pca.fit(E_scaled)

pca.explained_variance_.round(3)
# Out:
# array([2.065, 1.172, 0.263])
